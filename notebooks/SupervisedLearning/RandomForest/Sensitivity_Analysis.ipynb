# %%
from sklearn.metrics import confusion_matrix, f1_score
import matplotlib.pyplot as plt
import seaborn as sns 
import pandas as pd
import numpy as np
import joblib

import warnings
warnings.filterwarnings('ignore')

# %%
root_directory = '../../../data/train_test_split/'

X_train_transformed = pd.read_csv(root_directory+'x_train_rf.csv')
y_train = pd.read_csv(root_directory+'y_train.csv')['is_drafted']

X_test_transformed = pd.read_csv(root_directory+'x_test_rf.csv')
y_test = pd.read_csv(root_directory+'y_test.csv')['is_drafted']

# %%
# Sensitivity Analysis - Randomized Search with CV
from sklearn.ensemble import RandomForestClassifier
from sklearn.model_selection import RandomizedSearchCV
from sklearn.metrics import make_scorer, f1_score

clf = RandomForestClassifier()

# Define the parameter grid for RandomizedSearchCV
# Expanded parameter grid for RandomizedSearchCV
param_dist = {
    'n_estimators': [50, 75, 100, 150],  # How many trees
    'max_depth': [10, 15, 20, 30, 50, 75],  # How many splits in the trees are allowed
    'min_samples_split': [10, 15, 20],  # More options for minimum samples split
    'min_samples_leaf': [3, 8, 10],  # How many samples are allowed to comprise a leaf
    'bootstrap': [True],  # Whether bootstrap samples are used
    'max_features': ['sqrt'],  # Different ways to limit the number of features considered at each split
    'criterion': ['entropy'],  # Different criteria for splitting nodes
    'class_weight': ['balanced']
}


# Randomized Search cross validation

random_search = RandomizedSearchCV(
    clf, 
    param_distributions=param_dist, 
    n_iter=100,  # Number of parameter settings sampled
    scoring="f1_micro",  # Optimize for f1 score (weight
    cv=3,  # 5-fold cross-validation
    random_state=0, 
    n_jobs=-1,  # Use all available cores
)

# # Assuming you have X_train and y_train already defined
random_search.fit(X_train_transformed, y_train)

# Extracting results from GridSearchCV
results = pd.DataFrame(random_search.cv_results_)

# %%
results.shape
# Out:
# (100, 19)

# %%
cols = ['param_n_estimators', 'param_min_samples_split', 'param_min_samples_leaf', 'param_max_depth',
        'mean_test_score', 'rank_test_score']

results = results[cols]

# %%
results.head()
# Out:
#   param_n_estimators param_min_samples_split param_min_samples_leaf  \
# 0                150                      15                      8
# 1                 75                      10                      3
# 2                 75                      15                      8
# 3                 75                      10                     10
# 4                 50                      20                      3
#
#   param_max_depth  mean_test_score  rank_test_score
# 0              75         0.884253               34
# 1              15         0.892998               24
# 2              20         0.883975               35
# 3              50         0.873893               68
# 4              50         0.894558               21

# %%
import altair as alt

# %%
rename_dict = {'param_n_estimators': 'num_trees',
               'param_min_samples_split': 'min_samples_split',
               'param_min_samples_leaf': 'min_samples_leaf',
               'param_max_depth': 'max_depth',
              'mean_test_score': 'f1 score'}

results = results.rename(rename_dict, axis = 1)
results.head()
# Out:
#   num_trees min_samples_split min_samples_leaf max_depth  f1 score  \
# 0       150                15                8        75  0.884253
# 1        75                10                3        15  0.892998
# 2        75                15                8        20  0.883975
# 3        75                10               10        50  0.873893
# 4        50                20                3        50  0.894558
#
#    rank_test_score
# 0               34
# 1               24
# 2               35
# 3               68
# 4               21

# %%
a = alt.Chart(results).mark_rect().encode(
    x='max_depth:O',
    y='num_trees:Q',
    color='mean(f1 score)'
    ).properties(height = 200, width = 200)

b = alt.Chart(results).mark_rect().encode(
    x='max_depth:O',
    y='min_samples_split:Q',
    color='mean(f1 score)'
    ).properties(height = 200, width = 200)

c = alt.Chart(results).mark_rect().encode(
    x='max_depth:O',
    y='min_samples_leaf:Q',
    color='mean(f1 score)'
    ).properties(height = 200, width = 200)

x = a|b|c

x.properties(title = 'Average f1 Score of Models: Broken Down by Max Depth Value vs All Other Parameters*').configure_title(fontSize=20)\
    .configure_axis(
    labelFontSize=16,
    titleFontSize=16
)
# Out:
# alt.HConcatChart(...)

# %%
a = alt.Chart(results).mark_rect().encode(
    x='num_trees:O',
    y='min_samples_split:O',
    color='mean(mean_test_score)'
    ).properties(height = 200, width = 200)

b = alt.Chart(results).mark_rect().encode(
    x='num_trees:O',
    y='min_samples_leaf:O',
    color='mean(mean_test_score)'
    ).properties(height = 200, width = 200)

c = alt.Chart(results).mark_rect().encode(
    x='num_trees:O',
    y='max_depth:O',
    color='mean(mean_test_score)'
    ).properties(height = 200, width = 200)

a|b|c
# Out:
# alt.HConcatChart(...)

# %%
a = alt.Chart(results).mark_rect().encode(
    x='min_samples_leaf:O',
    y='min_samples_leaf:O',
    color='mean(mean_test_score)'
    ).properties(height = 200, width = 200)

b = alt.Chart(results).mark_rect().encode(
    x='min_samples_split:O',
    y='max_depth:O',
    color='mean(mean_test_score)'
    ).properties(height = 200, width = 200)


a|b
# Out:
# alt.HConcatChart(...)

# %%
alt.Chart(results).mark_rect().encode(
    x='min_samples_leaf:O',
    y='max_depth:O',
    color='mean(mean_test_score)'
    ).properties(height = 200, width = 200)
# Out:
# alt.Chart(...)

# %%
# Sensitivity Analysis - Randomized Search with CV
from sklearn.ensemble import RandomForestClassifier
from sklearn.model_selection import RandomizedSearchCV
from sklearn.metrics import make_scorer, f1_score

clf = RandomForestClassifier()

# Define the parameter grid for RandomizedSearchCV
# Expanded parameter grid for RandomizedSearchCV
param_dist = {
    'n_estimators': [50, 75, 100, 150],  # How many trees
    'max_depth': [10, 15, 20, 30],  # How many splits in the trees are allowed
    'min_samples_split': [10, 15, 20],  # More options for minimum samples split
    'min_samples_leaf': [8, 10],  # How many samples are allowed to comprise a leaf
    'bootstrap': [True, False],  # Whether bootstrap samples are used
    'max_features': [sqrt', 'log2', None],  # Different ways to limit the number of features considered at each split
    'criterion': ['gini', 'entropy'],  # Different criteria for splitting nodes
    'class_weight': ['balanced']
}


# Randomized Search cross validation

random_search = RandomizedSearchCV(
    clf, 
    param_distributions=param_dist, 
    n_iter=100,  # Number of parameter settings sampled
    scoring="f1_micro",  # Optimize for f1 score (weight
    cv=3,  # 5-fold cross-validation
    random_state=0, 
    n_jobs=-1,  # Use all available cores
)

# # Assuming you have X_train and y_train already defined
random_search.fit(X_train_transformed, y_train)

# Extracting results from GridSearchCV
results_all_params = pd.DataFrame(random_search.cv_results_)

results_all_params.head()
# Out:
#    mean_fit_time  std_fit_time  mean_score_time  std_score_time  \
# 0       3.145970      0.091797         0.114244        0.006125
# 1       3.131213      0.058297         0.156384        0.008420
# 2       5.032048      0.082188         0.158257        0.011457
# 3       2.355835      0.071120         0.110611        0.002601
# 4       2.522644      0.007489         0.111255        0.007847
#
#   param_n_estimators param_min_samples_split param_min_samples_leaf  \
# 0                100                      20                      8
# 1                150                      10                      8
# 2                150                      10                     10
# 3                100                      15                      8
# 4                150                      20                     10
#
#   param_max_features param_max_depth param_criterion param_class_weight  \
# 0               sqrt              15         entropy           balanced
# 1               sqrt              15         entropy           balanced
# 2               sqrt              30         entropy           balanced
# 3               log2              15            gini           balanced
# 4               sqrt              10         entropy           balanced
#
#   param_bootstrap                                             params  \
# 0           False  {'n_estimators': 100, 'min_samples_split': 20,...
# 1            True  {'n_estimators': 150, 'min_samples_split': 10,...
# 2           False  {'n_estimators': 150, 'min_samples_split': 10,...
# 3           False  {'n_estimators': 100, 'min_samples_split': 15,...
# 4            True  {'n_estimators': 150, 'min_samples_split': 20,...
#
#    split0_test_score  split1_test_score  split2_test_score  mean_test_score  \
# 0           0.856307           0.860127           0.844084         0.853506
# 1           0.880368           0.880849           0.871825         0.877680
# 2           0.865664           0.868483           0.859291         0.864479
# 3           0.854637           0.859960           0.847761         0.854119
# 4           0.829574           0.835561           0.818349         0.827828
#
#    std_test_score  rank_test_score
# 0        0.006842               59
# 1        0.004145               16
# 2        0.003845               37
# 3        0.004994               58
# 4        0.007135               70

# %%
results_all_params.columns
# Out:
# Index(['mean_fit_time', 'std_fit_time', 'mean_score_time', 'std_score_time',
#        'param_n_estimators', 'param_min_samples_split',
#        'param_min_samples_leaf', 'param_max_features', 'param_max_depth',
#        'param_criterion', 'param_class_weight', 'param_bootstrap', 'params',
#        'split0_test_score', 'split1_test_score', 'split2_test_score',
#        'mean_test_score', 'std_test_score', 'rank_test_score', 'f1_rounded'],
#       dtype='object')

# %%
# 80% fall between f1-scores of .80 and .90

results_all_params['f1_rounded'] = results_all_params['mean_test_score'].round(2)
a = results_all_params.groupby(by = 'f1_rounded').agg({'params':'count'}).reset_index()

a['pct_total'] = a['params'] / 100

alt.Chart(a).mark_bar(size = 10).encode(
    x = alt.Y('f1_rounded', title = 'Mean CV f1 score (3-fold)'),
    y = alt.Y('pct_total', title = '% of Models')).properties(
    width = 320, height = 400, title = 'Distribution of f1-scores on 100 trained models').configure_title(fontSize=18)
# Out:
# alt.Chart(...)

# %%
# 21 of the 30 worst-performing models had max depth of 10.

alt.Chart(results_all_params).mark_bar().encode(
    x = alt.Y('f1_rounded', title = 'Mean CV f1 score (3-fold)', bin=alt.Bin(maxbins=25)),
    y = alt.Y('count()', title = '# of Models'),
    color = 'param_max_depth:N').properties(height = 200, width = 400, title = 'Model Performance by Max Depth Param Values').configure_title(fontSize=18)
# Out:
# alt.Chart(...)

# %%
# Bottom 30 models and the params that led to it:

results_all_params.sort_values(by = 'mean_test_score')[['param_n_estimators', 'param_min_samples_split',
       'param_min_samples_leaf', 'param_max_features', 'param_max_depth',
       'param_criterion', 'param_class_weight', 'param_bootstrap']].head(30)
# Out:
#    param_n_estimators param_min_samples_split param_min_samples_leaf  \
# 59                100                      20                      8
# 72                 50                      20                      8
# 75                100                      15                      8
# 42                 75                      15                     10
# 51                150                      10                      8
# 89                 50                      10                     10
# 19                 50                      15                      8
# 29                100                      15                     10
# 76                 50                      20                      8
# 43                150                      10                      8
# 62                100                      20                     10
# 30                 50                      10                     10
# 5                 150                      10                     10
# 94                150                      15                     10
# 35                150                      10                     10
# 47                100                      15                      8
# 18                 50                      15                     10
# 91                 75                      20                      8
# 13                150                      20                     10
# 54                 75                      20                     10
# 27                150                      15                     10
# 65                100                      20                      8
# 45                 50                      10                     10
# 37                150                      10                      8
# 57                 75                      10                     10
# 60                100                      20                     10
# 49                 50                      15                      8
# 55                100                      10                     10
# 38                 50                      20                     10
# 21                100                      10                     10
#
#    param_max_features param_max_depth param_criterion param_class_weight  \
# 59               None              10            gini           balanced
# 72               None              10            gini           balanced
# 75               None              10            gini           balanced
# 42               None              10            gini           balanced
# 51               None              10         entropy           balanced
# 89               None              10         entropy           balanced
# 19               None              10         entropy           balanced
# 29               None              15         entropy           balanced
# 76               None              15         entropy           balanced
# 43               None              15            gini           balanced
# 62               None              20            gini           balanced
# 30               None              20         entropy           balanced
# 5                None              20            gini           balanced
# 94               None              20         entropy           balanced
# 35               None              30            gini           balanced
# 47               None              20         entropy           balanced
# 18               sqrt              10         entropy           balanced
# 91               log2              10         entropy           balanced
# 13               log2              10         entropy           balanced
# 54               sqrt              10         entropy           balanced
# 27               log2              10         entropy           balanced
# 65               sqrt              10         entropy           balanced
# 45               log2              10         entropy           balanced
# 37               sqrt              10         entropy           balanced
# 57               log2              10            gini           balanced
# 60               log2              10            gini           balanced
# 49               sqrt              10            gini           balanced
# 55               sqrt              10            gini           balanced
# 38               sqrt              10         entropy           balanced
# 21               sqrt              10         entropy           balanced
#
#    param_bootstrap
# 59           False
# 72           False
# 75           False
# 42           False
# 51           False
# 89           False
# 19           False
# 29           False
# 76           False
# 43           False
# 62           False
# 30           False
# 5            False
# 94           False
# 35           False
# 47           False
# 18           False
# 91           False
# 13           False
# 54           False
# 27           False
# 65           False
# 45           False
# 37           False
# 57           False
# 60           False
# 49           False
# 55           False
# 38            True
# 21            True

# %%
results_all_params.sort_values(by = 'mean_test_score', ascending = True).head(30)
# Out:
#     mean_fit_time  std_fit_time  mean_score_time  std_score_time  \
# 59      14.404406      0.244905         0.085834        0.004404
# 72       7.611088      0.272133         0.055501        0.005492
# 75      14.524488      0.090089         0.097533        0.003668
# 42      11.344990      0.261275         0.076888        0.003026
# 51      24.998441      0.426494         0.137282        0.010245
# 89       7.998067      0.089562         0.042825        0.003081
# 19       7.873020      0.087363         0.048242        0.011468
# 29      19.480526      0.353396         0.098593        0.006116
# 76      10.870728      0.182828         0.052533        0.003370
# 43      26.908381      0.187222         0.169345        0.017107
# 62      18.203714      0.372692         0.138173        0.036585
# 30      10.419793      0.464853         0.056008        0.004886
# 5       22.927712      0.264329         0.157776        0.019166
# 94      30.791581      0.738501         0.118230        0.029488
# 35      26.930652      0.203849         0.153025        0.004755
# 47      23.986578      0.935322         0.114569        0.005372
# 18       1.320269      0.018024         0.048627        0.003325
# 91       1.813855      0.025078         0.068281        0.005242
# 13       3.478116      0.043026         0.103245        0.002684
# 54       2.089846      0.013421         0.077867        0.001415
# 27       3.289111      0.004107         0.129217        0.002479
# 65       2.889719      0.061108         0.108143        0.003525
# 45       1.212597      0.016052         0.051451        0.002822
# 37       4.055901      0.061774         0.133804        0.006958
# 57       1.566027      0.031454         0.069487        0.004250
# 60       2.135099      0.078650         0.104426        0.012574
# 49       1.321930      0.043305         0.064247        0.008473
# 55       2.389815      0.029902         0.103078        0.009683
# 38       0.982962      0.019316         0.049111        0.001260
# 21       1.998343      0.074246         0.113122        0.009825
#
#    param_n_estimators param_min_samples_split param_min_samples_leaf  \
# 59                100                      20                      8
# 72                 50                      20                      8
# 75                100                      15                      8
# 42                 75                      15                     10
# 51                150                      10                      8
# 89                 50                      10                     10
# 19                 50                      15                      8
# 29                100                      15                     10
# 76                 50                      20                      8
# 43                150                      10                      8
# 62                100                      20                     10
# 30                 50                      10                     10
# 5                 150                      10                     10
# 94                150                      15                     10
# 35                150                      10                     10
# 47                100                      15                      8
# 18                 50                      15                     10
# 91                 75                      20                      8
# 13                150                      20                     10
# 54                 75                      20                     10
# 27                150                      15                     10
# 65                100                      20                      8
# 45                 50                      10                     10
# 37                150                      10                      8
# 57                 75                      10                     10
# 60                100                      20                     10
# 49                 50                      15                      8
# 55                100                      10                     10
# 38                 50                      20                     10
# 21                100                      10                     10
#
#    param_max_features param_max_depth param_criterion  ... param_bootstrap  \
# 59               None              10            gini  ...           False
# 72               None              10            gini  ...           False
# 75               None              10            gini  ...           False
# 42               None              10            gini  ...           False
# 51               None              10         entropy  ...           False
# 89               None              10         entropy  ...           False
# 19               None              10         entropy  ...           False
# 29               None              15         entropy  ...           False
# 76               None              15         entropy  ...           False
# 43               None              15            gini  ...           False
# 62               None              20            gini  ...           False
# 30               None              20         entropy  ...           False
# 5                None              20            gini  ...           False
# 94               None              20         entropy  ...           False
# 35               None              30            gini  ...           False
# 47               None              20         entropy  ...           False
# 18               sqrt              10         entropy  ...           False
# 91               log2              10         entropy  ...           False
# 13               log2              10         entropy  ...           False
# 54               sqrt              10         entropy  ...           False
# 27               log2              10         entropy  ...           False
# 65               sqrt              10         entropy  ...           False
# 45               log2              10         entropy  ...           False
# 37               sqrt              10         entropy  ...           False
# 57               log2              10            gini  ...           False
# 60               log2              10            gini  ...           False
# 49               sqrt              10            gini  ...           False
# 55               sqrt              10            gini  ...           False
# 38               sqrt              10         entropy  ...            True
# 21               sqrt              10         entropy  ...            True
#
#                                                params split0_test_score  \
# 59  {'n_estimators': 100, 'min_samples_split': 20,...          0.664996
# 72  {'n_estimators': 50, 'min_samples_split': 20, ...          0.664996
# 75  {'n_estimators': 100, 'min_samples_split': 15,...          0.665998
# 42  {'n_estimators': 75, 'min_samples_split': 15, ...          0.672682
# 51  {'n_estimators': 150, 'min_samples_split': 10,...          0.715288
# 89  {'n_estimators': 50, 'min_samples_split': 10, ...          0.713784
# 19  {'n_estimators': 50, 'min_samples_split': 15, ...          0.715789
# 29  {'n_estimators': 100, 'min_samples_split': 15,...          0.762072
# 76  {'n_estimators': 50, 'min_samples_split': 20, ...          0.763743
# 43  {'n_estimators': 150, 'min_samples_split': 10,...          0.768588
# 62  {'n_estimators': 100, 'min_samples_split': 20,...          0.757561
# 30  {'n_estimators': 50, 'min_samples_split': 10, ...          0.764912
# 5   {'n_estimators': 150, 'min_samples_split': 10,...          0.757728
# 94  {'n_estimators': 150, 'min_samples_split': 15,...          0.765414
# 35  {'n_estimators': 150, 'min_samples_split': 10,...          0.763074
# 47  {'n_estimators': 100, 'min_samples_split': 15,...          0.775940
# 18  {'n_estimators': 50, 'min_samples_split': 15, ...          0.795656
# 91  {'n_estimators': 75, 'min_samples_split': 20, ...          0.794152
# 13  {'n_estimators': 150, 'min_samples_split': 20,...          0.795656
# 54  {'n_estimators': 75, 'min_samples_split': 20, ...          0.794820
# 27  {'n_estimators': 150, 'min_samples_split': 15,...          0.791980
# 65  {'n_estimators': 100, 'min_samples_split': 20,...          0.794820
# 45  {'n_estimators': 50, 'min_samples_split': 10, ...          0.799165
# 37  {'n_estimators': 150, 'min_samples_split': 10,...          0.796825
# 57  {'n_estimators': 75, 'min_samples_split': 10, ...          0.801003
# 60  {'n_estimators': 100, 'min_samples_split': 20,...          0.799332
# 49  {'n_estimators': 50, 'min_samples_split': 15, ...          0.801504
# 55  {'n_estimators': 100, 'min_samples_split': 10,...          0.803509
# 38  {'n_estimators': 50, 'min_samples_split': 20, ...          0.820718
# 21  {'n_estimators': 100, 'min_samples_split': 10,...          0.825564
#
#     split1_test_score  split2_test_score  mean_test_score  std_test_score  \
# 59           0.651237           0.656751         0.657661        0.005654
# 72           0.651237           0.657420         0.657884        0.005627
# 75           0.652574           0.657253         0.658608        0.005564
# 42           0.647894           0.657754         0.659443        0.010190
# 51           0.637032           0.704378         0.685566        0.034607
# 89           0.638536           0.704378         0.685566        0.033476
# 19           0.637032           0.704378         0.685733        0.034751
# 29           0.719251           0.691845         0.724389        0.028899
# 76           0.724766           0.696524         0.728344        0.027558
# 43           0.731618           0.711063         0.737090        0.023801
# 62           0.743316           0.744820         0.748565        0.006390
# 30           0.745321           0.735963         0.748732        0.012062
# 5            0.743316           0.745488         0.748844        0.006344
# 94           0.745655           0.736297         0.749122        0.012137
# 35           0.746992           0.746491         0.752186        0.007702
# 47           0.773229           0.736130         0.761766        0.018161
# 18           0.794953           0.785595         0.792068        0.004586
# 91           0.795956           0.789439         0.793182        0.002748
# 13           0.797293           0.788937         0.793962        0.003615
# 54           0.796457           0.792948         0.794742        0.001434
# 27           0.802473           0.792447         0.795633        0.004840
# 65           0.806150           0.787099         0.796023        0.007824
# 45           0.800468           0.790608         0.796747        0.004373
# 37           0.806651           0.789773         0.797750        0.006921
# 57           0.803142           0.797627         0.800590        0.002270
# 60           0.809325           0.796123         0.801593        0.005622
# 49           0.806317           0.798964         0.802262        0.003049
# 55           0.809993           0.796791         0.803431        0.005390
# 38           0.826537           0.809659         0.818972        0.007000
# 21           0.835394           0.818683         0.826547        0.006858
#
#     rank_test_score  f1_rounded  shallow_tree_flag
# 59              100        0.66                  1
# 72               99        0.66                  1
# 75               98        0.66                  1
# 42               97        0.66                  1
# 51               96        0.69                  1
# 89               95        0.69                  1
# 19               94        0.69                  1
# 29               93        0.72                  0
# 76               92        0.73                  0
# 43               91        0.74                  0
# 62               90        0.75                  0
# 30               89        0.75                  0
# 5                88        0.75                  0
# 94               87        0.75                  0
# 35               86        0.75                  0
# 47               85        0.76                  0
# 18               84        0.79                  1
# 91               83        0.79                  1
# 13               82        0.79                  1
# 54               81        0.79                  1
# 27               80        0.80                  1
# 65               79        0.80                  1
# 45               78        0.80                  1
# 37               77        0.80                  1
# 57               76        0.80                  1
# 60               75        0.80                  1
# 49               74        0.80                  1
# 55               73        0.80                  1
# 38               72        0.82                  1
# 21               71        0.83                  1
#
# [30 rows x 21 columns]
