# %%
# %load_ext autoreload
# %autoreload 2

# %reload_ext autoreload

# %% [markdown]
# # Support Vector Machine (SVM) Model

# %%
# Uncomment to get the correct versions
from IPython.display import clear_output
# !pip install -r ../requirements.txt
clear_output()

# %%
import pandas as pd 
import numpy as np
from sklearn.model_selection import train_test_split, cross_val_score
from sklearn.preprocessing import StandardScaler
from sklearn.svm import SVC
from sklearn.metrics import accuracy_score, classification_report, confusion_matrix, f1_score, precision_score

# %%
pd.set_option('display.max_columns', None)
pd.set_option('display.max_rows', None)

# %%
# Get the data

x_train_path = '../../data/train_test_split/x_train_cluster.csv'
y_train_path = '../../data/train_test_split/y_train.csv'

x_test_path = '../../data/train_test_split/x_test_cluster.csv'
y_test_path = '../../data/train_test_split/y_test.csv'

x_train_df = pd.read_csv(x_train_path) 
y_train_df = pd.read_csv(y_train_path) 

x_test_df = pd.read_csv(x_test_path)
y_test_df = pd.read_csv(y_test_path)

# %%
x_train_df['dataset_type'] = 'train'
x_test_df['dataset_type'] = 'test'

# Combine train and test
train_df = pd.merge(x_train_df, y_train_df, how='left', left_index=True, right_index=True)
test_df = pd.merge(x_test_df, y_test_df,how='left', left_index=True, right_index=True)

# %%
# Convert all the clusters into objects
train_df['KMeans_Cluster'] = train_df['KMeans_Cluster'].astype(object)
test_df['KMeans_Cluster'] = test_df['KMeans_Cluster'].astype(object)

train_df['SVD_KMeans_Cluster'] = train_df['SVD_KMeans_Cluster'].astype(object)
test_df['SVD_KMeans_Cluster'] = test_df['SVD_KMeans_Cluster'].astype(object)

train_df['DBSCAN_Cluster_PCA'] = train_df['DBSCAN_Cluster_PCA'].astype(object)
test_df['DBSCAN_Cluster_PCA'] = test_df['DBSCAN_Cluster_PCA'].astype(object)

# %%
combined_df = pd.concat([train_df, test_df], axis=0)
combined_df.reset_index(drop=True, inplace=True)

# %%
combined_df.head()
# Out:
#    Unnamed: 0.1              name  rating  ranking  year position  height  \
# 0           361      C.J. Prosise  0.8915    365.0  2012        S    74.0
# 1         14685     Jaylon Haynes  0.8166   1684.0  2017       DT    73.0
# 2         15617      Nasser Clark  0.7667   3299.0  2017       RB    70.0
# 3          3870  Courtney Miggins  0.8111   1568.0  2013      SDE    77.0
# 4         20038       Zaylin Wood  0.8383   1429.0  2019      SDE    74.0
#
#    weight   latitude  longitude     hometown_city state_province  \
# 0   190.0  35.166812 -80.751458  Woodberry Forest             VA
# 1   290.0  29.312480 -96.098238           Wharton             TX
# 2   190.0  34.597245 -83.763306         Cleveland             GA
# 3   240.0  33.712331 -84.105194          Lithonia             GA
# 4   262.0  33.537889 -85.253282            Bowdon             GA
#
#   hometown_country  stars      committed_to  athlete_id         conference  \
# 0              USA      4        Notre Dame    535958.0   FBS Independents
# 1              USA      3              UTSA   4245215.0  American Athletic
# 2              USA      2              Army         NaN  American Athletic
# 3              USA      3         Louisiana         NaN           Sun Belt
# 4              USA      3  Middle Tennessee   4428925.0     Conference USA
#
#    latitude_school  longitude_school  wins_rolling_2year  \
# 0        41.698378        -86.233942                16.0
# 1        29.416983        -98.478814                 9.0
# 2        41.387492        -73.964089                10.0
# 3        30.215843        -92.041737                18.0
# 4        35.851146        -86.368165                15.0
#
#    games_played_rolling_2year  post_season_wins_rolling_2year  \
# 0                        26.0                             1.0
# 1                        25.0                             0.0
# 2                        25.0                             1.0
# 3                        26.0                             2.0
# 4                        27.0                             1.0
#
#    point_diff_rolling_2year  win_pct_rolling_2year  distance_miles  \
# 0                     190.0               0.615385      539.828641
# 1                    -118.0               0.360000      143.529399
# 2                      62.0               0.400000      709.669019
# 3                     128.0               0.692308      523.980272
# 4                      29.0               0.555556      171.919819
#
#   side_of_ball position_group DBSCAN_Cluster_PCA SVD_KMeans_Cluster  \
# 0      defense    d_backfield                  0                  1
# 1      defense         d_line                  0                  3
# 2      offense   running_back                  1                  3
# 3      defense         d_line                  0                  1
# 4      defense         d_line                  0                  1
#
#   KMeans_Cluster dataset_type  Unnamed: 0  is_drafted
# 0              2        train         361         1.0
# 1              1        train       14685         0.0
# 2              0        train       15617         0.0
# 3              1        train        3870         0.0
# 4              1        train       20038         0.0

# %%
combined_df.head()
# Out:
#    Unnamed: 0.1              name  rating  ranking  year position  height  \
# 0           361      C.J. Prosise  0.8915    365.0  2012        S    74.0
# 1         14685     Jaylon Haynes  0.8166   1684.0  2017       DT    73.0
# 2         15617      Nasser Clark  0.7667   3299.0  2017       RB    70.0
# 3          3870  Courtney Miggins  0.8111   1568.0  2013      SDE    77.0
# 4         20038       Zaylin Wood  0.8383   1429.0  2019      SDE    74.0
#
#    weight   latitude  longitude     hometown_city state_province  \
# 0   190.0  35.166812 -80.751458  Woodberry Forest             VA
# 1   290.0  29.312480 -96.098238           Wharton             TX
# 2   190.0  34.597245 -83.763306         Cleveland             GA
# 3   240.0  33.712331 -84.105194          Lithonia             GA
# 4   262.0  33.537889 -85.253282            Bowdon             GA
#
#   hometown_country  stars      committed_to  athlete_id         conference  \
# 0              USA      4        Notre Dame    535958.0   FBS Independents
# 1              USA      3              UTSA   4245215.0  American Athletic
# 2              USA      2              Army         NaN  American Athletic
# 3              USA      3         Louisiana         NaN           Sun Belt
# 4              USA      3  Middle Tennessee   4428925.0     Conference USA
#
#    latitude_school  longitude_school  wins_rolling_2year  \
# 0        41.698378        -86.233942                16.0
# 1        29.416983        -98.478814                 9.0
# 2        41.387492        -73.964089                10.0
# 3        30.215843        -92.041737                18.0
# 4        35.851146        -86.368165                15.0
#
#    games_played_rolling_2year  post_season_wins_rolling_2year  \
# 0                        26.0                             1.0
# 1                        25.0                             0.0
# 2                        25.0                             1.0
# 3                        26.0                             2.0
# 4                        27.0                             1.0
#
#    point_diff_rolling_2year  win_pct_rolling_2year  distance_miles  \
# 0                     190.0               0.615385      539.828641
# 1                    -118.0               0.360000      143.529399
# 2                      62.0               0.400000      709.669019
# 3                     128.0               0.692308      523.980272
# 4                      29.0               0.555556      171.919819
#
#   side_of_ball position_group DBSCAN_Cluster_PCA SVD_KMeans_Cluster  \
# 0      defense    d_backfield                  0                  1
# 1      defense         d_line                  0                  3
# 2      offense   running_back                  1                  3
# 3      defense         d_line                  0                  1
# 4      defense         d_line                  0                  1
#
#   KMeans_Cluster dataset_type  Unnamed: 0  is_drafted
# 0              2        train         361         1.0
# 1              1        train       14685         0.0
# 2              0        train       15617         0.0
# 3              1        train        3870         0.0
# 4              1        train       20038         0.0

# %%
train_df.head()
# Out:
#    Unnamed: 0.1              name  rating  ranking  year position  height  \
# 0           361      C.J. Prosise  0.8915    365.0  2012        S    74.0
# 1         14685     Jaylon Haynes  0.8166   1684.0  2017       DT    73.0
# 2         15617      Nasser Clark  0.7667   3299.0  2017       RB    70.0
# 3          3870  Courtney Miggins  0.8111   1568.0  2013      SDE    77.0
# 4         20038       Zaylin Wood  0.8383   1429.0  2019      SDE    74.0
#
#    weight   latitude  longitude     hometown_city state_province  \
# 0   190.0  35.166812 -80.751458  Woodberry Forest             VA
# 1   290.0  29.312480 -96.098238           Wharton             TX
# 2   190.0  34.597245 -83.763306         Cleveland             GA
# 3   240.0  33.712331 -84.105194          Lithonia             GA
# 4   262.0  33.537889 -85.253282            Bowdon             GA
#
#   hometown_country  stars      committed_to  athlete_id         conference  \
# 0              USA      4        Notre Dame    535958.0   FBS Independents
# 1              USA      3              UTSA   4245215.0  American Athletic
# 2              USA      2              Army         NaN  American Athletic
# 3              USA      3         Louisiana         NaN           Sun Belt
# 4              USA      3  Middle Tennessee   4428925.0     Conference USA
#
#    latitude_school  longitude_school  wins_rolling_2year  \
# 0        41.698378        -86.233942                16.0
# 1        29.416983        -98.478814                 9.0
# 2        41.387492        -73.964089                10.0
# 3        30.215843        -92.041737                18.0
# 4        35.851146        -86.368165                15.0
#
#    games_played_rolling_2year  post_season_wins_rolling_2year  \
# 0                        26.0                             1.0
# 1                        25.0                             0.0
# 2                        25.0                             1.0
# 3                        26.0                             2.0
# 4                        27.0                             1.0
#
#    point_diff_rolling_2year  win_pct_rolling_2year  distance_miles  \
# 0                     190.0               0.615385      539.828641
# 1                    -118.0               0.360000      143.529399
# 2                      62.0               0.400000      709.669019
# 3                     128.0               0.692308      523.980272
# 4                      29.0               0.555556      171.919819
#
#   side_of_ball position_group DBSCAN_Cluster_PCA SVD_KMeans_Cluster  \
# 0      defense    d_backfield                  0                  1
# 1      defense         d_line                  0                  3
# 2      offense   running_back                  1                  3
# 3      defense         d_line                  0                  1
# 4      defense         d_line                  0                  1
#
#   KMeans_Cluster dataset_type  Unnamed: 0  is_drafted
# 0              2        train         361         1.0
# 1              1        train       14685         0.0
# 2              0        train       15617         0.0
# 3              1        train        3870         0.0
# 4              1        train       20038         0.0

# %%
# Display the Target rates of the training and testing datast 
print('Training Conversion Rate: ', round(train_df['is_drafted'].mean(),4)* 100.0, '%')
print('Testing Conversion Rate: ', round(test_df['is_drafted'].mean(),4) * 100.0, '%')
# Out:
# Training Conversion Rate:  8.62 %
# Testing Conversion Rate:  8.24 %

# %%
numerical_features = ['rating', 'ranking', 'stars', 'games_played_rolling_2year','win_pct_rolling_2year']

# numerical_features = ['games_played_rolling_2year']
clusters = ['KMeans_Cluster', 'SVD_KMeans_Cluster', 'DBSCAN_Cluster_PCA']
categorical_features = ['position_group',  'state_province', 'side_of_ball']


features = numerical_features+clusters+categorical_features
target = ['is_drafted']

# %%
features
# Out:
# ['rating',
#  'ranking',
#  'stars',
#  'games_played_rolling_2year',
#  'win_pct_rolling_2year',
#  'KMeans_Cluster',
#  'SVD_KMeans_Cluster',
#  'DBSCAN_Cluster_PCA',
#  'position_group',
#  'state_province',
#  'side_of_ball']

# %%
print(len(features))
# Out:
# 11

# %% [markdown]
# ## Pre-process the data

# %%
from sklearn.compose import ColumnTransformer
from sklearn.preprocessing import StandardScaler, OneHotEncoder

# Transformer
preprocessor = ColumnTransformer(
    transformers=[
        ('num', StandardScaler(), numerical_features),
        ('cat', OneHotEncoder(handle_unknown='ignore'), categorical_features+clusters)
    ])

# %% [markdown]
# ## Prepare the data

# %%
# Separate features and target in the balanced dataset
X = train_df[features]
y = train_df[target]

# %%
# Pre-process the train and test datasets
X_train = preprocessor.fit_transform(X)

X_test = test_df[features]
X_test_processed = preprocessor.transform(X_test)

# %%
# Get the target variables
y_train = y.to_numpy().ravel()
y_test = test_df[['is_drafted']].to_numpy().ravel()

# %% [markdown]
# ### Hyperparameter Tuning

# %%
# %%time
# from sklearn.model_selection import GridSearchCV
# from sklearn.svm import SVC
# from sklearn.metrics import make_scorer, f1_score

# # Define hyperparameter grid
# param_grid = {
#     'kernel': ['linear', 'poly', 'rbf', 'sigmoid'],
#     'C': [0.01, 0.1, 1],  # Regularization parameter
#     'gamma': [0.001, 0.01,'scale', 'auto'],  # Kernel coefficient for non-linear kernels
#     'degree': [2, 3, 4]  # Degree for 'poly' kernel
# }

# # {'C': 0.1, 'degree': 3, 'gamma': 'auto', 'kernel': 'poly'}

# # Initialize SVC with class weight balancing
# svm_model = SVC(class_weight='balanced', random_state=42)
# scoring = make_scorer(f1_score, average='micro')

# # Perform grid search with 5-fold cross-validation
# grid_search = GridSearchCV(estimator=svm_model, param_grid=param_grid, 
#                            scoring=scoring, cv=5, n_jobs=-1)

# # Fit grid search to training data
# grid_search.fit(X_train, y_train)

# # Get the best parameters and score
# best_params = grid_search.best_params_
# best_score = grid_search.best_score_

# clear_output() 

# print("Best hyperparameters:", best_params)
# print(f"Best cross-validated F1 score: {best_score:.4f}")

# # Optional: Extract all the results
# cv_results = grid_search.cv_results_
# results_df = pd.DataFrame(cv_results)

# # Display the results
# results_df = results_df[['params', 'mean_test_score', 'rank_test_score']].sort_values(by='rank_test_score')
# print("All cross-validation results:")
# print(results_df)

# %%
# results_df.head()

# %%
# print(best_params)

# %%
best_params = {'C': 0.1, 'degree': 2, 'gamma': 'scale', 'kernel': 'linear'}

# %% [markdown]
# ## Best Model

# %%
# Initialize the SVM model with the kernel of your choice (linear, poly, rbf etc.)
svm_model = SVC(**best_params, class_weight='balanced', random_state=42)

# %%
# Train the model
svm_model.fit(X_train, y_train)

# Make predictions
y_pred_test = svm_model.predict(X_test_processed)

# %%
y_pred_train = svm_model.predict(X_train)

# %%
# ## Create a Model Pipeline
# from sklearn.pipeline import Pipeline

# model_pipeline = Pipeline(steps=[('preprocessor', preprocessor),
#                                  ('model', svm_model)])

# %%
# preprocessor = model_pipeline['preprocessor']
# svm_model = model_pipeline['model']

# %% [markdown]
# ## Model Performance
#
# Calculate/Visualize the following:
# - F1- Score (Cross val mean and std)
# - Confusion Matrix
# - Feature Importance

# %%
import evaluate_model as em

# %%
f1_score_test = em.calculate_f1_score(y_test , y_pred_test)
print('Test F1 Score:', f1_score_test)

f1_score_train = em.calculate_f1_score(y_train , y_pred_train)
print('Train F1 Score:', f1_score_train)
# Out:
# Test F1 Score: 0.8424394319131161
# Train F1 Score: 0.8455968361833677

# %%
# Show the model results 
model_scores, model_scores_mean, model_scores_std = em.evaluate_cross_val_score(svm_model, X_test_processed, y_test)

clear_output()
print('Mean F1 Score: ', model_scores_mean)
print('Std F1 Score', model_scores_std )
# Out:
# Mean F1 Score:  0.7246449456975773
# Std F1 Score 0.027263952038279103

# %%
# Create a confusion matrix 
conf_mat = em.create_confusion_matrix(y_test, y_pred_test)

# %%
# %%time

em.svm_feature_importance(svm_model, preprocessor,X, y, visualize=True)
# Out:
# CPU times: user 1h 16min 10s, sys: 103 ms, total: 1h 16min 10s
# Wall time: 1h 16min 10s
#                              Feature  Importance
# 80             cat__KMeans_Cluster_2    0.046421
# 79             cat__KMeans_Cluster_1    0.002417
# 78             cat__KMeans_Cluster_0    0.001526
# 81             cat__KMeans_Cluster_3    0.000345
# 37            cat__state_province_MA    0.000022
# 20            cat__state_province_BC    0.000011
# 65            cat__state_province_TX    0.000000
# 63            cat__state_province_SW    0.000000
# 62            cat__state_province_SD    0.000000
# 61            cat__state_province_SC    0.000000
# 60            cat__state_province_RI    0.000000
# 59            cat__state_province_QL    0.000000
# 58            cat__state_province_QC    0.000000
# 57            cat__state_province_PA    0.000000
# 56            cat__state_province_OR    0.000000
# 55            cat__state_province_ON    0.000000
# 54            cat__state_province_OK    0.000000
# 53            cat__state_province_OH    0.000000
# 52            cat__state_province_NY    0.000000
# 51            cat__state_province_NV    0.000000
# 50            cat__state_province_NM    0.000000
# 49            cat__state_province_NJ    0.000000
# 48            cat__state_province_NH    0.000000
# 47            cat__state_province_NE    0.000000
# 64            cat__state_province_TN    0.000000
# 88         cat__DBSCAN_Cluster_PCA_1    0.000000
# 87         cat__DBSCAN_Cluster_PCA_0    0.000000
# 86        cat__DBSCAN_Cluster_PCA_-1    0.000000
# 85         cat__SVD_KMeans_Cluster_3    0.000000
# 84         cat__SVD_KMeans_Cluster_2    0.000000
# 83         cat__SVD_KMeans_Cluster_1    0.000000
# 82         cat__SVD_KMeans_Cluster_0    0.000000
# 0                        num__rating    0.000000
# 77         cat__side_of_ball_special    0.000000
# 67            cat__state_province_VA    0.000000
# 75         cat__side_of_ball_defense    0.000000
# 74         cat__side_of_ball_athlete    0.000000
# 73           cat__state_province_nan    0.000000
# 72            cat__state_province_WY    0.000000
# 71            cat__state_province_WV    0.000000
# 70            cat__state_province_WI    0.000000
# 69            cat__state_province_WA    0.000000
# 68            cat__state_province_VC    0.000000
# 46            cat__state_province_ND    0.000000
# 66            cat__state_province_UT    0.000000
# 76         cat__side_of_ball_offense    0.000000
# 21            cat__state_province_CA    0.000000
# 19            cat__state_province_AZ    0.000000
# 18            cat__state_province_AS    0.000000
# 17            cat__state_province_AR    0.000000
# 16            cat__state_province_AL    0.000000
# 15            cat__state_province_AK    0.000000
# 14            cat__state_province_AB    0.000000
# 13       cat__position_group_special    0.000000
# 12  cat__position_group_running_back    0.000000
# 11            cat__position_group_qb    0.000000
# 44            cat__state_province_MT    0.000000
# 1                       num__ranking    0.000000
# 8     cat__position_group_linebacker    0.000000
# 7         cat__position_group_d_line    0.000000
# 6    cat__position_group_d_backfield    0.000000
# 5        cat__position_group_athlete    0.000000
# 4         num__win_pct_rolling_2year    0.000000
# 3    num__games_played_rolling_2year    0.000000
# 2                         num__stars    0.000000
# 89         cat__DBSCAN_Cluster_PCA_2    0.000000
# 9         cat__position_group_o_line    0.000000
# 10  cat__position_group_pass_catcher    0.000000
# 45            cat__state_province_NC    0.000000
# 43            cat__state_province_MS    0.000000
# 42            cat__state_province_MO    0.000000
# 41            cat__state_province_MN    0.000000
# 40            cat__state_province_MI    0.000000
# 39            cat__state_province_ME    0.000000
# 38            cat__state_province_MD    0.000000
# 36            cat__state_province_LA    0.000000
# 35            cat__state_province_KY    0.000000
# 34            cat__state_province_KS    0.000000
# 22            cat__state_province_CO    0.000000
# 32            cat__state_province_IL    0.000000
# 31            cat__state_province_ID    0.000000
# 30            cat__state_province_IA    0.000000
# 29            cat__state_province_HI    0.000000
# 28            cat__state_province_GA    0.000000
# 27            cat__state_province_FL    0.000000
# 26            cat__state_province_EN    0.000000
# 25            cat__state_province_DE    0.000000
# 24            cat__state_province_DC    0.000000
# 23            cat__state_province_CT    0.000000
# 33            cat__state_province_IN    0.000000
